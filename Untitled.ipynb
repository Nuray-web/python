# %%
from PIL import Image 
import PIL 
import os 
import glob


def compress_images(directory=False, quality=10):
    # 1. If there is a directory then change into it, else perform the next operations inside of the 
    # current working directory:
    if directory:
        os.chdir(directory)

    # 2. Extract all of the .png and .jpeg files:
    files = os.listdir()

    # 3. Extract all of the images:
    images = [file for file in files if file.endswith(('jpeg', 'png'))]

    # 4. Loop over every image:
    for image in images:
        print(image)

        # 5. Open every image:
        img = Image.open(image)

        # 5. Compress every image and save it with a new name:
        img.save("Compressed_and_resized_with_function_"+image, optimize=True, quality=quality)
        
subdirectory_path = r'C:\Users\nsyrymbet\Desktop\add'
print(subdirectory_path)

compress_images(directory=subdirectory_path)
# Out:
# C:\Users\nsyrymbet\Desktop\add
# 2744112.jpeg
# 2744312.jpeg
# 2744512.jpeg
# 2744712.jpeg
# 2744912.jpeg
# 2745112.jpeg
# 4090118.jpeg
# 4090120.jpeg
# 4090122.jpeg
# 4090124.jpeg
# 4090126.jpeg
# 4090128.jpeg
# 4090130.jpeg
# 4131810.jpeg
# 4131820.jpeg
# 4166120.jpeg
# 4166122.jpeg
# 4166124.jpeg
# 4166126.jpeg
# 4166128.jpeg
# 4166224.jpeg
# 4166522.jpeg
# 4166628.jpeg
# 4166924.jpeg
# 4166926.jpeg
# 4166928.jpeg
# 4170124.jpeg
# 4170126.jpeg
# 4170128.jpeg
# 4170224.jpeg
# 4170522.jpeg
# 4170924.jpeg
# 4170926.jpeg
# 4170928.jpeg
# 4182120.jpeg
# 4182122.jpeg
# 4182124.jpeg
# 4182126.jpeg
# 4182128.jpeg
# 4182224.jpeg
# 4182628.jpeg
# 4192124.jpeg
# 4192126.jpeg
# 4192128.jpeg
# 4192224.jpeg
# 4192525.jpeg
# 4192628.jpeg
# 4206124.jpeg
# 4206126.jpeg
# 4206128.jpeg
# 4206522.jpeg
# 4206628.jpeg
# 4212924.jpeg
# 4212926.jpeg
# 4212928.jpeg
# BJ551B10.jpeg
# MK622A32.jpeg
# PU4026.jpeg
# QA150110.jpeg
# TG803832.jpeg
# VF2310F0.jpeg
# ZR903501.jpeg

# %% [markdown]
# from PIL import Image
# import PIL
# import os
# import glob
#
# file_name = 'ZR903701-compressed.jpeg'
# picture = Image.open(r"C:\Users\nsyrymbet\Desktop\pic_notes\ZR903701.jpeg")
# dim = picture.size
# print(f"This is the current width and height of the image: {dim}")
#
# picture.save("Compressed_"+file_name,optimize=True,quality=10)
